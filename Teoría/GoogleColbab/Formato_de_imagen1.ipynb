# %%
import numpy as np
import cv2 as cv
import skimage.io as io
import matplotlib.pyplot as plt


# Dirección de la imagen
url = "https://www.politecnicojic.edu.co/images/fotos/2022/pico-y-placa-2022.jpg"
#        "https://media.istockphoto.com/photos/human-thoracic-cavity-xray-film-picture-id1212285302?k=20&m=1212285302&s=612x612&w=0&h=B-_y6dP3yy_bLKCmXxpXkS8tH-eAqlUrXHUGALrvutM="

# %%
image = io.imread(url)#lee la imagen de la url y la convierte una variable opencv multicanal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) #convierte la imagen a RGB para verse como es
cv.imshow("imagen",image)#muestra la imagen original adquirda de la url mediante opencv
cv.waitKey(0)
cv.destroyAllWindows()
cv.imshow("imagen",image_2)#muestra la imagen convertida a RGB
cv.waitKey(0)
cv.destroyAllWindows()
image_3 = cv.cvtColor(image_2, cv.COLOR_RGB2GRAY)#convierte la imagen a escala de grises
cv.imshow("imagen",image_3)#muestra la imagen convertida a escala de grises
cv.waitKey(0)#espera a que se presione una tecla
cv.destroyAllWindows()#cierra todas las ventanas

# %%
# Tipo de datos en la imagen
print('dtype:', image_2.dtype) #muestra el tipo de dato de la imagen
# Alto , Ancho de la imagen en píxeles , Número de canales de la imagen
print('shape:',image_2.shape)#(alto, ancho, canales) de la imagen
print('size:',image_2.size)#numero de pixeles de la imagen
# Out:
# dtype: uint8
# shape: (630, 1200, 3)
# size: 2268000

# %%
r,g,b = cv.split(image)#dividir la imagen en 3 canales
plt.figure(figsize=(10,10))#tamanio de la imagen
plt.imshow(b, cmap='gray')#muestra una capa de la imagen en escala de grises

# %%
COLORflags = [flag for flag in dir(cv) if flag.startswith('COLOR') ]
print(len(COLORflags))
print(COLORflags)
# Out:
# 396
# ...
